# %% [markdown]
# <a href="https://colab.research.google.com/github/ZungLV/AI/blob/main/AI_LeVietDung_20146237_W5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 7.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=cb9f277f014380bc025c96aa35958427cc3d4af9f71921125855b6428b3f2ba3
#   Stored in directory: /root/.cache/pip/wheels/2c/04/80/7eefb1a2de7d36aefd06432fab2a1486caf0a0596a7067391a
# Successfully built scikit-fuzzy
# ...

# %%
# Medical Diagnosis System Using Fuzzy Logic
#bao thu vien
import numpy as np
import skfuzzy as fz
import matplotlib.pyplot as plt
from skfuzzy import control as ctrl

#tao bien dau vao Fever
Fever = ctrl.Antecedent(np.arange(0,1.1,0.05),'Fever')
#tao gia tri cho tung phan tu Fever
Fever['Mild']=fz.trimf(Fever.universe,[0.1,0.2,0.3])
Fever['Moderate']=fz.trimf(Fever.universe,[0.3,0.45,0.6])
Fever['Severe']=fz.trimf(Fever.universe,[0.6,0.7,0.8])
Fever['Very Severe']=fz.trimf(Fever.universe,[0.8,0.9,1])

#tao bien dau vao Headache
Headache = ctrl.Antecedent(np.arange(0,1.1,0.05),'Headache')
#tao gia tri cho tung phan tu Headache
Headache['Mild']=fz.trimf(Headache.universe,[0.1,0.2,0.3])
Headache['Moderate']=fz.trimf(Headache.universe,[0.3,0.45,0.6])
Headache['Severe']=fz.trimf(Headache.universe,[0.6,0.7,0.8])
Headache['Very Severe']=fz.trimf(Headache.universe,[0.8,0.9,1])

#tao bien dau vao Nausea
Nausea = ctrl.Antecedent(np.arange(0,1.1,0.05),'Nausea')
#tao gia tri cho tung phan tu Nausea
Nausea['Mild']=fz.trimf(Nausea.universe,[0.1,0.2,0.3])
Nausea['Moderate']=fz.trimf(Nausea.universe,[0.3,0.45,0.6])
Nausea['Severe']=fz.trimf(Nausea.universe,[0.6,0.7,0.8])
Nausea['Very Severe']=fz.trimf(Nausea.universe,[0.8,0.9,1])

#tao bien dau vao Vomiting
Vomiting = ctrl.Antecedent(np.arange(0,1.1,0.05),'Vomiting')
#tao gia tri cho tung phan tu Vomiting
Vomiting['Mild']=fz.trimf(Vomiting.universe,[0.1,0.2,0.3])
Vomiting['Moderate']=fz.trimf(Vomiting.universe,[0.3,0.45,0.6])
Vomiting['Severe']=fz.trimf(Vomiting.universe,[0.6,0.7,0.8])
Vomiting['Very Severe']=fz.trimf(Vomiting.universe,[0.8,0.9,1])

#tao bien dau vao Jaundice
Jaundice = ctrl.Antecedent(np.arange(0,1.1,0.05),'Jaundice')
#tao gia tri cho tung phan tu Jaundice
Jaundice['Mild']=fz.trimf(Jaundice.universe,[0.1,0.2,0.3])
Jaundice['Moderate']=fz.trimf(Jaundice.universe,[0.3,0.45,0.6])
Jaundice['Severe']=fz.trimf(Jaundice.universe,[0.6,0.7,0.8])
Jaundice['Very Severe']=fz.trimf(Jaundice.universe,[0.8,0.9,1])

#tao bien dau vao Enlarge Liver
Enlarge_Liver = ctrl.Antecedent(np.arange(0,1.1,0.05),'Enlarge Liver')
#tao gia tri cho tung phan tu Enlarge Liver
Enlarge_Liver['Mild']=fz.trimf(Enlarge_Liver.universe,[0.1,0.2,0.3])
Enlarge_Liver['Moderate']=fz.trimf(Enlarge_Liver.universe,[0.3,0.45,0.6])
Enlarge_Liver['Severe']=fz.trimf(Enlarge_Liver.universe,[0.6,0.7,0.8])
Enlarge_Liver['Very Severe']=fz.trimf(Enlarge_Liver.universe,[0.8,0.9,1])

#tao bien dau vao Joint Pain
Joint_Pain = ctrl.Antecedent(np.arange(0,1.1,0.05),'Joint Pain')
#tao gia tri cho tung phan tu Joint Pain
Joint_Pain['Mild']=fz.trimf(Joint_Pain.universe,[0.1,0.2,0.3])
Joint_Pain['Moderate']=fz.trimf(Joint_Pain.universe,[0.3,0.45,0.6])
Joint_Pain['Severe']=fz.trimf(Joint_Pain.universe,[0.6,0.7,0.8])
Joint_Pain['Very Severe']=fz.trimf(Joint_Pain.universe,[0.8,0.9,1])

#tao bien dau vao Body Weakness
Body_Weakness = ctrl.Antecedent(np.arange(0,1.1,0.05),'Body Weakness')
#tao gia tri cho tung phan tu Body Weakness
Body_Weakness['Mild']=fz.trimf(Body_Weakness.universe,[0.1,0.2,0.3])
Body_Weakness['Moderate']=fz.trimf(Body_Weakness.universe,[0.3,0.45,0.6])
Body_Weakness['Severe']=fz.trimf(Body_Weakness.universe,[0.6,0.7,0.8])
Body_Weakness['Very Severe']=fz.trimf(Body_Weakness.universe,[0.8,0.9,1])

#tao bien dau vao Dizziness
Dizziness = ctrl.Antecedent(np.arange(0,1.1,0.05),'Dizziness')
#tao gia tri cho tung phan tu Dizziness
Dizziness['Mild']=fz.trimf(Dizziness.universe,[0.1,0.2,0.3])
Dizziness['Moderate']=fz.trimf(Dizziness.universe,[0.3,0.45,0.6])
Dizziness['Severe']=fz.trimf(Dizziness.universe,[0.6,0.7,0.8])
Dizziness['Very Severe']=fz.trimf(Dizziness.universe,[0.8,0.9,1])

#tao bien dau vao Loss of Appetite
Loss_of_Appetite = ctrl.Antecedent(np.arange(0,1.1,0.05),'Loss of Appetite')
#tao gia tri cho tung phan tu Loss of Appetite
Loss_of_Appetite['Mild']=fz.trimf(Loss_of_Appetite.universe,[0.1,0.2,0.3])
Loss_of_Appetite['Moderate']=fz.trimf(Loss_of_Appetite.universe,[0.3,0.45,0.6])
Loss_of_Appetite['Severe']=fz.trimf(Loss_of_Appetite.universe,[0.6,0.7,0.8])
Loss_of_Appetite['Very Severe']=fz.trimf(Loss_of_Appetite.universe,[0.8,0.9,1])

#tao bien dau vao Loss of MP
MP = ctrl.Antecedent(np.arange(0,1.1,0.05),'MP')
#tao gia tri cho tung phan tu MP
MP['Mild']=fz.trimf(MP.universe,[0.1,0.2,0.3])
MP['Moderate']=fz.trimf(MP.universe,[0.3,0.45,0.6])
MP['Severe']=fz.trimf(MP.universe,[0.6,0.7,0.8])
MP['Very Severe']=fz.trimf(MP.universe,[0.8,0.9,1])

#tao bien dau ra Conclusion
Conclusion = ctrl.Consequent(np.arange(0,1.1,0.05),'Conclusion')
#tao gia tri cho tung phan tu Conclusion
Conclusion['Mild']=fz.trimf(Conclusion.universe,[0.1,0.2,0.3])
Conclusion['Moderate']=fz.trimf(Conclusion.universe,[0.3,0.45,0.6])
Conclusion['Severe']=fz.trimf(Conclusion.universe,[0.6,0.7,0.8])
Conclusion['Very Severe']=fz.trimf(Conclusion.universe,[0.8,0.9,1])
Conclusion.view()

#tao 20 luat
rule1=ctrl.Rule(Fever['Mild']&Headache['Mild']&Nausea['Mild']&Vomiting['Mild']&Jaundice['Mild']&Enlarge_Liver['Mild']&Joint_Pain['
&Jaundice['Mild']&Enlarge_Liver['Mild']&Joint_Pain['Mild']&Body_Weakness['Moderate']&Dizziness['Mild']&Loss_of_Appetite['Moderate']&MP['Moderate'],Conclusion['Moderate'])
rule14=ctrl.Rule(Fever['Severe']&Headache['Severe']&Nausea['Moderate']&Vomiting['Severe']&Jaundice['Severe']&Enlarge_Liver['Severe']&Joint_Pain['Severe']&Body_Weakness['Severe']&Dizziness['Moderate']&Loss_of_Appetite['Moderate']&MP['Severe'],Conclusion['Severe'])
rule15=ctrl.Rule(Fever['Mild']&Headache['Mild']&Nausea['Mild']&Vomiting['Moderate']&Jaundice['Mild']&Enlarge_Liver['Mild']&Joint_Pain['Mild']&Body_Weakness['Severe']&Dizziness['Mild']&Loss_of_Appetite['Severe']&MP['Moderate'],Conclusion['Severe'])
rule16=ctrl.Rule(Fever['Very Severe']&Headache['Moderate']&Nausea['Mild']&Vomiting['Moderate']&Jaundice['Severe']&Enlarge_Liver['Moderate']&Joint_Pain['Mild']&Body_Weakness['Very Severe']&Dizziness['Severe']&Loss_of_Appetite['Mild']&MP['Moderate'],Conclusion['Very Severe'])
rule17=ctrl.Rule(Fever['Mild']&Headache['Very Severe']&Nausea['Moderate']&Vomiting['Moderate']&Jaundice['Mild']&Enlarge_Liver['Moderate']&Joint_Pain['Mild']&Body_Weakness['Moderate']&Dizziness['Very Severe']&Loss_of_Appetite['Mild']&MP['Moderate'],Conclusion['Very Severe'])
rule18=ctrl.Rule(Fever['Moderate']&Headache['Very Severe']&Nausea['Very Severe']&Vomiting['Mild']&Jaundice['Severe']&Enlarge_Liver['Severe']&Joint_Pain['Moderate']&Body_Weakness['Severe']&Dizziness['Very Severe']&Loss_of_Appetite['Very Severe']&MP['Severe'],Conclusion['Very Severe'])
rule19=ctrl.Rule(Fever['Moderate']&Headache['Moderate']&Nausea['Moderate']&Vomiting['Moderate']&Jaundice['Mild']&Enlarge_Liver['Mild']&Joint_Pain['Moderate']&Body_Weakness['Moderate']&Dizziness['Moderate']&Loss_of_Appetite['Moderate']&MP['Moderate'],Conclusion['Moderate'])
rule20=ctrl.Rule(Fever['Very Severe']&Headache['Severe']&Nausea['Severe']&Vomiting['Severe']&Jaundice['Severe']&Enlarge_Liver['Severe']&Joint_Pain['Severe']&Body_Weakness['Severe']&Dizziness['Severe']&Loss_of_Appetite['Severe']&MP['Moderate'],Conclusion['Very Severe'])

#tao system ctrl
Concl_ctrl=ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule19,rule20])
Concl=ctrl.ControlSystemSimulation(Concl_ctrl)
#tao input
Concl.input['Fever']=0.4
Concl.input['Headache']=0.4 
Concl.input['Nausea']=0.4
Concl.input['Vomiting']=0.4
Concl.input['Jaundice']=0.4
Concl.input['Enlarge Liver']=0.4
Concl.input['Joint Pain']=0.4
Concl.input['Body Weakness']=0.4
Concl.input['Dizziness']=0.4
Concl.input['Loss of Appetite']=0.4 
Concl.input['MP']=0.4
#tinh toan
Concl.compute()
#in gia tri voi bieu do
print(Concl.output['Conclusion'])
Conclusion.view(sim=Concl)
# Out:
# 0.44999999999999996
